# %% [markdown]
# ### 문제 3-1 :  콘텐츠분쟁해결 RAG 시스템 - 간단 실습 가이드

# %%
print("콘텐츠분쟁해결 사례집을 활용한 법률 자문 RAG 시스템을 순차적으로 구축하는 실습입니다.")
# Out:
# 콘텐츠분쟁해결 사례집을 활용한 법률 자문 RAG 시스템을 순차적으로 구축하는 실습입니다.

# %%
import os
from dotenv import load_dotenv

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(OPENAI_API_KEY[:2])
# Out:
# sk

# %%
import os
import json
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from pprint import pprint

pdf_path = '..\data\콘텐츠분쟁해결_사례.pdf'

if not os.path.exists(pdf_path):
    raise FileNotFoundError(f"{pdf_path}라는 파일이 존재하지 않습니다. ")
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\d'
# <>:7: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\user\AppData\Local\Temp\ipykernel_12456\3309375398.py:7: SyntaxWarning: invalid escape sequence '\d'
#   pdf_path = '..\data\콘텐츠분쟁해결_사례.pdf'

# %%
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate

try: 
    # PyPDFLoader 인스턴스 객체를 반환해서 loader 변수의 메모리에 할당
    loader = PyPDFLoader(pdf_path)
    # print(f"type(loader): {type(loader)}") # type(loader): <class 'langchain_community.document_loaders.pdf.PyPDFLoader'>
    
    # loader 인스턴스를 Document 객체 리스트로 변환
    docs = loader.load()
    # print(f"type(docs): {type(docs)}") # type(docs): <class 'list'>
    # print(f"문서 타입: {type(docs[0])}") # 문서 타입: <class 'langchain_core.documents.base.Document'>
    
    # 첫 번째 문서의 메타데이터 출력하기
    # print(json.dumps(docs[0].metadata, indent=4, ensure_ascii=False))
    
    # docs의 길이
    # print(f"len(docs): {len(docs)}") # len(docs): 109
    
    # 한 번 출력해보기
    # if docs[10]:
    #     pprint(docs[10])
    
    # 1단계: 문서 분할 설정
    # 1-1. 분할기 생성
    pythontext_splitter = RecursiveCharacterTextSplitter(   
        chunk_size = 1500,      # 청크 크기 (최대 길이): 1500자
        chunk_overlap=300,      # 맥락 보존을 위해 중복 단어 300개까지 허용
        separators=[
            "\n【사건개요】",     # 법률 문서 섹션 구분자
            "\n【쟁점사항】",     # 쟁점 부분 구분
            "\n【처리경위】",     # 처리 과정 구분
            "\n【처리결과】",     # 결과 부분 구분
            "\n■", "\n\n", "\n", ".", " ", "" # 자연스러운 분할을 위해 추가
        ]
    )
    # 1-2. 분할기 적용
    chunks = pythontext_splitter.split_documents(documents=docs)
    
    # 2단계: 임베딩 모델 설정
    python_embeddings = OpenAIEmbeddings(
        model="text-embedding-3-large", # 고성능 임베딩 모델로 설정
        
        # 고성능 임베딩 벡터 차원(20000차원) 
        # "Invalid value for 'dimensions' = 20000. Must be less than or equal to 3072."
        # 최대 3072 차원까지 가능
        # dimensions=20000
        dimensions=3072 # 최대 3072 차원까지 가능해서 최대 차원(3072)으로 설정
    )
    
    # 저장 단계: 저장하기
        # documents 매개변수에 입력 된 chunks의 텍스트를 
        # embedding에 입력 된 python_embeddings 모델을 사용하여 
        # 컴퓨터가 읽을 수 있도록 3072차원의 숫자 배열(임베딩 백터)로 변환 후
        # FAISS라는 검색 속도 향상 클래스로 더욱 빠르게 찾을 수 있도록 구조화 후
        # vector_store 변수의 메모리에 저장
    vector_store = FAISS.from_documents(documents=chunks, embedding=python_embeddings)
    
    # 3단계: 검색기 설정
    python_retriever = vector_store.as_retriever(
        # search_type="similarity", # search_type의 default 값인 "similarity" 말고
        search_type="mmr",  # 다양성을 고려하여 mmr 알고리즘 적용
        search_kwargs={
            "k": 5,         # 테스트 객체 중 가장 관련성이 높고 다양한 상위 5개의 Document 객체 반환
            "fetch_k":30    # 30개의 Document 객체를 테스트 가져오고
            }
    )
    
    # 4단계: LLM 설정
    python_llm = ChatOpenAI(
        model="gpt-4o",     # 모델은 gpt-4o
        temperature=0,      # 창의적이게 하지 말고
        max_tokens=1500     # 충분한 답변 길이를 반환해라
    )
    
    # 5단계: 법률 자문 프롬프트 작성
    pythonprompt_template = """
        당신은 콘텐츠 분야 전문 법률 자문사입니다. 
        아래 분쟁조정 사례들을 바탕으로 정확하고 전문적인 법률 조언을 제공해주세요.

        관련 분쟁사례:
        {context}

        상담 내용: {question}

        답변 가이드라인:
        1. 제시된 사례들을 근거로 답변하세요                    # 사례 기반 답변
        2. 관련 법령이나 조항이 있다면 명시하세요               # 법적 근거 제시
        3. 비슷한 사례의 처리경위와 결과를 참고하여 설명하세요    # 판례 참조
        4. 실무적 해결방안을 단계별로 제시하세요               #  실무 가이드
        5. 사례에 없는 내용은 "제시된 사례집에서는 확인할 수 없습니다"라고 명시하세요  #  한계 인정

        
        
        전문 법률 조언:
        """
    # 법률 자문 프롬프트 템플릿 생성
    prompt = PromptTemplate(
        template=pythonprompt_template,
        input_variables=["context", "question"]
    )

    # 6단계: QA 체인 생성
    python_qa_chain = RetrievalQA.from_chain_type(
        llm=python_llm,     # python_llm으로 정의한 모델 사용
        retriever=python_retriever, # 리트리버가 가져온 모든 문서
        chain_type="stuff", # 리트리버가 가져온 모든 문서를 그대로 llm 모델에 전달
        chain_type_kwargs={"prompt": prompt},   # 프롬프트 입력
        return_source_documents=True    # 참조 문서도 반환
    )
    
    # 7단계: 테스트 질문 작성
    pythontest_questions = [
        "온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?",
        "인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?",
        "무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?",
        "미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?",
        "온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?"
    ]

    # 8단계: 분쟁 유형 분류 함수
    def classify_dispute_type(query):
        game_keywords = ["게임", "아이템", "계정", "캐릭터", "레벨", "길드", "온라인게임"]
        elearning_keywords = ["강의", "온라인교육", "이러닝", "수강", "환불", "화상교육"]
        web_keywords = ["웹사이트", "무료체험", "자동결제", "구독", "사이트"]
        
        query_lower = query.lower()
        
        if any(keyword in query_lower for keyword in game_keywords):
            return "게임"
        elif any(keyword in query_lower for keyword in elearning_keywords):
            return "이러닝"
        elif any(keyword in query_lower for keyword in web_keywords):
            return "웹콘텐츠"
        else:
            return "기타"
        


    for q_num, question in enumerate(pythontest_questions, 1):
        
        print(f"질문 {q_num}. ")
        print(f"{question}")
        print("-"*100)    

        dispute_type = classify_dispute_type(question) # 질문 유형 분류
        
        # 유형에 따른 추가 정보 제공
        if dispute_type == "게임":
            print(f"분쟁 유형: {dispute_type}\t\t\t게임 관련 분쟁 유형은 게임사에 문의하시길 바랍니다. ")
        elif dispute_type == "이러닝":
            print(f"분쟁 유형: {dispute_type}\t\t\t이러닝 관련 분쟁 유형은 이러닝 강의를 진행하고 있는 학원사에 문의하시길 바랍니다. ")
        elif dispute_type == "웹콘텐츠":
            print(f"분쟁 유형: {dispute_type}\t\t\t웹 콘텐츠 관련 분쟁 유형은 해당 웹 콘텐츠를 개발하고 있는 개발사에 문의하시길 바랍니다. ")
        else: 
            print(f"분쟁 유형: {dispute_type}\t\t\t기타 분쟁 유형은 각각의 알맞은 곳에 문의하시길 바랍니다. ")
        
        print("-"*100)
        result = python_qa_chain.invoke({"query": question})
        answer = result["result"]
        source_docs = result["source_documents"]
        
        print("답변: ")
        print(f"{answer}")
        print("-"*100)    
        
        print("\t참조 문서: ")
        for doc_num, doc in enumerate(source_docs[:3], 1):
            print("-"*100)    
            # 각 Document 객체의 metadata 필드에서 'page'값을 가져오고 없으면 'N/A'로 설정
            page = doc.metadata.get('page', 'N/A')
            # 각 Document 객체의 page_content에서 처음 100글자를 가져와 줄바꿈을 공백으로 대체해서 미리보기로 저장
            preview = doc.page_content[:100].replace('\n', '\t')
            # 출력
            print(f"\t\t{doc_num}. 페이지 {page}: {preview}...")


        print("="*100)
    
except Exception as e:
    print(f"에러 발생: {e}")
# Out:
# 질문 1.
# 온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?
# ----------------------------------------------------------------------------------------------------
# 분쟁 유형: 게임			게임 관련 분쟁 유형은 게임사에 문의하시길 바랍니다.
# ----------------------------------------------------------------------------------------------------
# 답변:
# 전문 법률 조언:
#
# 1. **사례 기반 답변**:
#    - 제시된 사례 중 "시스템 오류로 소멸된 아이템 복구 요구" 사례를 참고할 수 있습니다. 이 사례에서는 신청인이 시스템 오류로 인해 소멸된 아이템의 복구를 요구했으나, 계정 명의자가 아니어서 복구가 거부된 상황이 있었습니다. 이 경우, 계정 명의자가 직접 복구 요청을 해야 한다는 점이 강조되었습니다.
#
# 2. **법적 근거 제시**:
#    - 관련 법령으로는 "약관의 규제에 관한 법률" 제11조가 있으며, 이는 고객의 권익 보호를 목적으로 합니다. 또한, "소비자분쟁해결기준" (공정위고시 제2010-1호)도 참고할 수 있습니다.
#
# 3. **판례 참조**:
#    - 비슷한 사례로는 "2009_시스템 오류로 인한 손실 아이템 복구 요구"가 있습니다. 이 사례에서는 시스템 오류로 인한 손실에 대해 복구를 요구했으나, 계정 명의자가 아니면 복구가 불가하다는 점이 확인되었습니다.
#
# 4. **실무 가이드**:
#    - **1단계**: 계정 명의 확인 - 본인이 계정 명의자가 아니라면, 명의자에게 복구 요청을 하도록 안내합니다.
#    - **2단계**: 게임 회사의 고객센터에 공식적으로 복구 요청을 합니다. 이때, 시스템 오류로 인한 손실임을 명확히 설명하고, 관련 증거(예: 오류 발생 시점의 스크린샷 등)를 제출합니다.
#    - **3단계**: 게임 회사의 약관을 검토하여, 복구 불가 사유가 약관에 명시되어 있는지 확인합니다.
#    - **4단계**: 만약 게임 회사가 복구를 거부할 경우, "소비자분쟁조정위원회"에 분쟁 조정을 신청할 수 있습니다. 이때, 관련 법령과 사례를 근거로 하여 주장을 강화합니다.
#
# 5. **한계 인정**:
#    - 제시된 사례집에서는 시스템 오류로 인한 아이템 소멸에 대한 복구가 명의자 문제 외에 다른 이유로 거부된 사례는 확인할 수 없습니다. 추가적인 법적 조언이 필요할 경우, 전문 변호사와 상담하는 것이 좋습니다.
# ----------------------------------------------------------------------------------------------------
# 	참조 문서:
# ----------------------------------------------------------------------------------------------------
# 		1. 페이지 8: 1. 게임	3	게임1	■ 1-가-1) 한국소비자원 조정전 상담사례2006_시스템 오류로 소멸된 아이템 복구 요구【사건개요】신청인은 피신청인이 제공하는 온라인게임서비스를 이용하던 중...
# ----------------------------------------------------------------------------------------------------
# 		2. 페이지 2: . 한국소비자원1) 조정전 상담사례2006_시스템 오류로 소멸된 아이템 복구 요구··················································32006...
# ----------------------------------------------------------------------------------------------------
# 		3. 페이지 40: 1. 게임	35	그 외에 자동 프로그램 사용으로 인한 계정 이용제한 시 이용요금을 환불하지 않을 수 있다는 피신청인의 이용약관에 대해서는 일종의 위약벌 내지 손해배상액의 예정 조항...
# ====================================================================================================
# 질문 2.
# 인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?
# ----------------------------------------------------------------------------------------------------
# 분쟁 유형: 이러닝			이러닝 관련 분쟁 유형은 이러닝 강의를 진행하고 있는 학원사에 문의하시길 바랍니다.
# ----------------------------------------------------------------------------------------------------
# 답변:
# 전문 법률 조언:
#
# 1. **사례 기반 답변**:
#    제시된 사례들에서 인터넷 강의 중도 해지 시 과도한 위약금을 요구받는 경우가 여러 차례 발생하였습니다. 특히, 2007년 인터넷교육서비스 중도해지 요구 사례에서는 피청구인이 위약금, 월교육비, 화상교육비, 가입비, 사은품 비용 등을 공제하고 환급해 주겠다고 하여 분쟁이 발생하였습니다. 이 사례에서는 피청구인의 공제 금액이 과도하다고 판단되어 조정이 이루어졌습니다.
#
# 2. **법적 근거 제시**:
#    - 방문판매 등에 관한 법률 제29조: 계약의 해지
#    - 소비자기본법에 따른 소비자분쟁해결기준(공정위고시, 인터넷콘텐츠업)
#
# 3. **판례 참조**:
#    위 사례에서는 소비자피해보상규정에 따라 '해지 일까지의 이용일수에 해당하는 금액과 총이용금액의 10% 공제 후 환급'이 기준이 되었습니다. 또한, 사은품 미사용 시 반환 규정이 적용되었습니다. 피청구인이 과도한 금액을 공제하려는 시도는 받아들여지지 않았습니다.
#
# 4. **실무 가이드**:
#    - **계약서 검토**: 먼저 계약서에 명시된 해지 및 환불 조건을 확인하세요.
#    - **공제 금액 확인**: 위약금 및 기타 공제 항목이 과도한지 검토하세요. 소비자보호법에 따른 기준을 참고하여 과도한 공제가 아닌지 판단합니다.
#    - **조정 요청**: 과도한 공제가 이루어졌다면, 소비자보호원이나 전자거래분쟁조정위원회에 조정을 요청할 수 있습니다.
#    - **법적 조치 고려**: 조정이 원활하지 않을 경우, 법적 조치를 고려할 수 있습니다. 이 경우, 변호사와 상담하여 법적 절차를 진행하는 것이 좋습니다.
#
# 5. **한계 인정**:
#    제시된 사례집에서는 특정한 위약금의 정당성 여부에 대한 구체적인 기준이나 금액은 확인할 수 없습니다. 각 사례의 구체적인 계약 조건과 상황에 따라 다를 수 있으므로, 개별적인 법률 상담이 필요할 수 있습니다.
# ----------------------------------------------------------------------------------------------------
# 	참조 문서:
# ----------------------------------------------------------------------------------------------------
# 		1. 페이지 3: . 이러닝·······························································································...
# ----------------------------------------------------------------------------------------------------
# 		2. 페이지 93: 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 -	88	■ 2-다 전자거래분쟁조정위원회 조정결정례2008_온라인 동영상 강의 계약 해지 청구【사건개요】신청인은 2008. ...
# ----------------------------------------------------------------------------------------------------
# 		3. 페이지 103: 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 -	98	뿐만 아니라 이용자가 가입 후 해지를 원할 때 일정기간 해지를 못하게 한다거나 해지 신청 상담 전화번호를 부정확하게...
# ====================================================================================================
# 질문 3.
# 무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?
# ----------------------------------------------------------------------------------------------------
# 분쟁 유형: 이러닝			이러닝 관련 분쟁 유형은 이러닝 강의를 진행하고 있는 학원사에 문의하시길 바랍니다.
# ----------------------------------------------------------------------------------------------------
# 답변:
# 전문 법률 조언:
#
# 1. **사례 기반 답변**:
#    - 제시된 사례에서, 신청인은 무료 체험 후 자동으로 유료 전환되어 요금이 청구된 경우에 대해 환불을 요구하였습니다. 이와 유사한 사례에서, 피신청인이 무료 이벤트 기간 내 해지하지 않을 경우 자동으로 유료 전환된다는 사실을 명확히 고지하지 않았다는 점이 문제로 지적되었습니다.
#
# 2. **법적 근거 제시**:
#    - 관련 법령으로는 "약관의 규제에 대한 법률 제3조 약관의 작성 및 설명의무"와 "소비자기본법에 따른 소비자분쟁해결기준"이 있습니다. 이 법령들은 계약 체결 시 중요한 내용을 명시하고 고지할 의무가 있음을 규정하고 있습니다.
#
# 3. **판례 참조**:
#    - 유사한 사례에서, 피신청인이 계약 해지에 대한 내용을 고지하였더라도 그 내용이 쉽게 확인하기 어려운 방식으로 제공되었다면, 이는 고지의무를 다하지 않은 것으로 판단되었습니다. 따라서, 신청인의 요구에 따라 일정 부분 환불이 이루어졌습니다.
#
# 4. **실무 가이드**:
#    - **1단계**: 서비스 제공자에게 무료 체험 후 자동 유료 전환에 대한 고지 여부를 확인합니다. 고지가 명확하지 않거나 확인이 어려운 경우, 이를 근거로 환불을 요청할 수 있습니다.
#    - **2단계**: 관련 법령과 소비자분쟁해결기준을 근거로 하여, 서비스 제공자에게 환불을 요구하는 공식적인 서면 요청을 제출합니다.
#    - **3단계**: 서비스 제공자가 환불을 거부할 경우, 한국소비자원이나 공정거래위원회에 분쟁 조정을 신청하여 중재를 요청합니다.
#    - **4단계**: 분쟁 조정 결과에 따라 환불이 이루어지지 않을 경우, 법적 절차를 고려할 수 있습니다.
#
# 5. **한계 인정**:
#    - 제시된 사례집에서는 특정 서비스의 약관이나 고지 방식에 대한 구체적인 내용은 확인할 수 없습니다. 따라서, 개별 사례에 대한 세부적인 검토가 필요합니다.
#
# 이와 같은 절차를 통해, 무료 체험 후 자동 유료 전환으로 인한 요금 청구 문제를 해결할 수 있을 것입니다.
# ----------------------------------------------------------------------------------------------------
# 	참조 문서:
# ----------------------------------------------------------------------------------------------------
# 		1. 페이지 100: 3. 기타(웹)	95	■ 3-가 한국소비자원 조정결정례2010_무료 이벤트 후 자동 소액 결제 요금 환급요구【사건개요】신청인은 2008. 12. 29. 피신청인 1이 운영하는 음악...
# ----------------------------------------------------------------------------------------------------
# 		2. 페이지 3: . 이러닝·······························································································...
# ----------------------------------------------------------------------------------------------------
# 		3. 페이지 40: 1. 게임	35	그 외에 자동 프로그램 사용으로 인한 계정 이용제한 시 이용요금을 환불하지 않을 수 있다는 피신청인의 이용약관에 대해서는 일종의 위약벌 내지 손해배상액의 예정 조항...
# ====================================================================================================
# 질문 4.
# 미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?
# ----------------------------------------------------------------------------------------------------
# 분쟁 유형: 게임			게임 관련 분쟁 유형은 게임사에 문의하시길 바랍니다.
# ----------------------------------------------------------------------------------------------------
# 답변:
# 전문 법률 조언:
#
# 1. **사례 기반 답변**:
#    - 제시된 사례에서 미성년자가 부모의 동의 없이 타인의 명의를 도용하여 게임 아이템을 구매한 경우, 이는 법정대리인의 동의 없이 이루어진 미성년자의 법률 행위로 간주될 수 있습니다. 따라서 이러한 행위는 취소가 가능하며, 부당이득으로서 환불을 요구할 수 있습니다.
#
# 2. **법적 근거 제시**:
#    - **민법 제5조**: 미성년자의 능력에 관한 규정으로, 미성년자는 법정대리인의 동의 없이 법률 행위를 할 수 없습니다.
#    - **민법 제741조**: 부당이득의 내용으로, 법률상 원인 없이 타인의 재산이나 이익을 얻은 경우 이를 반환해야 합니다.
#    - **민법 제753조 및 제755조**: 미성년자의 책임능력 및 책임무능력자의 감독자의 책임에 관한 규정입니다.
#
# 3. **판례 참조**:
#    - 대법원 판례(1971. 12. 14. 선고 71다2045 판결)에 따르면, 미성년자가 사술로써 능력자임을 믿게 했거나 법정대리인의 동의가 있는 것으로 믿게 한 경우에는 취소할 수 없다고 규정하고 있습니다. 그러나 단순히 능력자라 칭한 것만으로는 사술을 쓴 것으로 보지 않습니다.
#
# 4. **실무 가이드**:
#    - **1단계**: 게임사에 환불 요청을 합니다. 이때, 미성년자가 부모의 동의 없이 결제를 진행했음을 증명할 수 있는 자료(예: 결제 내역, 미성년자임을 증명할 수 있는 서류 등)를 준비합니다.
#    - **2단계**: 게임사가 환불을 거부할 경우, 전자거래분쟁조정위원회에 조정을 신청할 수 있습니다. 이때, 관련 법령과 판례를 근거로 환불의 정당성을 주장합니다.
#    - **3단계**: 조정이 이루어지지 않을 경우, 법적 절차를 통해 환불을 요구할 수 있습니다. 이 과정에서 법률 전문가의 도움을 받는 것이 좋습니다.
#
# 5. **한계 인정**:
#    - 제시된 사례집에서는 미성년자가 부모의 동의 없이 게임 아이템을 구매한 경우에 대한 구체적인 환불 절차나 결과에 대한 정보는 확인할 수 없습니다. 추가적인 사례나 정보를 원하시면 관련 기관에 문의하시기 바랍니다.
# ----------------------------------------------------------------------------------------------------
# 	참조 문서:
# ----------------------------------------------------------------------------------------------------
# 		1. 페이지 50: 1. 게임	45	■ 1-나 전자거래분쟁조정위원회 조정결정례2008_부당결제대금 반환 청구【사건개요】신청인의 자녀는 2004. 4. 22. 피신청인이 운영하는 게임 사이트에 가명으로...
# ----------------------------------------------------------------------------------------------------
# 		2. 페이지 2: . 한국소비자원1) 조정전 상담사례2006_시스템 오류로 소멸된 아이템 복구 요구··················································32006...
# ----------------------------------------------------------------------------------------------------
# 		3. 페이지 54: 1. 게임	49	 · 민법 제103조 및 제105조 ; 반사회적 법률행위와 부당이득 · 대법원 1971. 12. 14. 선고71다2045판결 · 전자상거래등에서의 소비자 보호 지침...
# ====================================================================================================
# 질문 5.
# 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?
# ----------------------------------------------------------------------------------------------------
# 분쟁 유형: 기타			기타 분쟁 유형은 각각의 알맞은 곳에 문의하시길 바랍니다.
# ----------------------------------------------------------------------------------------------------
# 답변:
# 전문 법률 조언:
#
# 1. **사례 기반 답변**:
#    제시된 사례들에 따르면, 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고자 하는 경우, 계약 해지 및 환불이 가능할 수 있습니다. 특히, 소비자가 서비스를 전혀 이용하지 않았거나, 서비스 제공자가 계약상 의무를 다하지 않은 경우에는 환불이 가능할 수 있습니다.
#
# 2. **법적 근거 제시**:
#    - **할부 거래에 관한 법률**: 이 법률은 간접할부계약 및 할부거래의 표시와 관련된 규정을 포함하고 있으며, 청약철회에 대한 규정도 명시하고 있습니다.
#    - **약관의 규제에 관한 법률**: 약관의 작성 및 설명의무, 약관의 해석에 대한 규정을 포함하고 있습니다.
#    - **소비자기본법**: 소비자분쟁해결기준에 따라 소비자 피해보상 규정이 적용될 수 있습니다.
#
# 3. **판례 참조**:
#    - 2008년 온라인 동영상 강의 계약 해지 청구 사례에서는, 신청인이 강의를 전혀 듣지 않았고 교재도 훼손하지 않은 상태에서 환불을 요청하였으나, 피신청인이 계약을 성실히 이행하였다는 이유로 환불을 거부한 사례가 있습니다. 이 경우, 소비자피해보상 규정에 따라 철회권 행사의 제한이 적용되었습니다.
#    - 2009년 공정거래위원회는 온라인 음원 제공업자의 서비스 이용 약관 중 유료서비스 중도해지 제한조항을 시정 권고한 바 있습니다.
#
# 4. **실무 가이드**:
#    - **1단계**: 계약서 및 약관 검토 - 계약서와 약관을 검토하여 청약철회 및 해지 조건을 확인합니다.
#    - **2단계**: 서비스 제공자와의 협의 - 서비스 제공자에게 계약 해지 및 환불 요청을 공식적으로 전달합니다.
#    - **3단계**: 분쟁조정 신청 - 협의가 원활하지 않을 경우, 전자거래분쟁조정위원회에 분쟁조정을 신청합니다.
#    - **4단계**: 법적 조치 검토 - 분쟁조정 결과에 만족하지 않을 경우, 법적 조치를 검토합니다.
#
# 5. **한계 인정**:
#    제시된 사례집에서는 광고와 다르게 제공된 온라인 교육 서비스에 대한 구체적인 해지 가능 여부를 확인할 수 없습니다. 추가적인 사례나 법적 자문이 필요할 수 있습니다.
# ----------------------------------------------------------------------------------------------------
# 	참조 문서:
# ----------------------------------------------------------------------------------------------------
# 		1. 페이지 94: 2. 이러닝	89	상기 내용을 살펴보면, 신청인은 청약철회 기간을 지났으므로 위 계약의 청약을 철회할 수는 없는 것으로 보인다. 피신청인은 위 계약에 따라 정해진 기간 내에 신청인...
# ----------------------------------------------------------------------------------------------------
# 		2. 페이지 3: . 이러닝·······························································································...
# ----------------------------------------------------------------------------------------------------
# 		3. 페이지 103: 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 -	98	뿐만 아니라 이용자가 가입 후 해지를 원할 때 일정기간 해지를 못하게 한다거나 해지 신청 상담 전화번호를 부정확하게...
# ====================================================================================================
